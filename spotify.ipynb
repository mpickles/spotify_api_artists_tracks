# %%
import os
import dotenv
from dotenv import load_dotenv
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data
from tqdm.notebook import tqdm
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time
import random

# %%
# get client id and client secret
load_dotenv()
client_id= os.environ.get("SPOTIPY_CLIENT_ID")
client_secret = os.environ.get("SPOTIPY_SECRET")

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API

# %%
def artist_all_tracks(artist):
    
    '''
    Takes a list of artist names, iterates through their Spotify albums (including
    singles, compilations and collaborations), checks for duplicate albums, then
    appends all the tracks in those albums to a list of lists
    '''
    
    # Each list in this list will be a track and its features
    tracks = []
        
    # Get the artist URI (a unique ID)
    artist_uri = sp.search(artist)['tracks']['items'][0]['artists'][0]['uri']

    # Spotify has a lot of duplicate albums, but we'll cross-reference them with this list to avoid extra loops
    album_checker = []
    
    # The starting point of our loop of albums for those artists with more than 50
    n = 0
    
    # Note that here we include singles, compilations and collaborations in the albums to loop through
    while len(sp.artist_albums(artist_uri, album_type = ['album', 'single'], limit=50, offset = n)['items']) > 0:
        
        # Avoid overloading Spotify with requests by assigning the list of album dictionaries to a variable
        dict_list = sp.artist_albums(artist_uri, album_type = ['album', 'single'], limit=50, offset = n)['items']

        for i, album in tqdm(enumerate(dict_list)):

            # Add the featured artists for the album in question to the checklist
            check_this_album = [j['name'] for j in dict_list[i]['artists']]
            # And the album name
            check_this_album.append(dict_list[i]['name'])
            # And its date
            check_this_album.append(dict_list[i]['release_date'])

            # Only continue looping if that album isn't in the checklist
            if check_this_album not in album_checker:
    
                # Add this album to the checker
                album_checker.append(check_this_album)

                # for every song in an album, return data about the album, song title, and song uri
                for song in sp.album_tracks(album['uri'])['items']:
                    tracks.extend([[artist, album['name'], album['uri'], album['release_date'], song['name'], song['uri']]])

                # For every song on the album, get its descriptors and features in a list and add to the tracklist
                # tracks.extend([[artist, album['name'], album['uri'], ['name'], album['release_date']] 
                #   + list(sp.audio_features(sp.album_tracks(album['uri'])['items'].values())) ])
        
        # Go through the next 50 albums (otherwise we'll get an infinite while loop)
        n += 50

    return tracks

# %%
def df_tracks(tracklist):
    
    '''
    Takes the output of artist_tracks (i.e. a list of lists),
    puts it in a dataframe and formats it.
    '''

    df = pd.DataFrame(tracklist, columns=['artist',
     'album_name',
     'album_uri',
     'release_date',
     'track',
     'song_uri',
     ] 
     
    #  + list(sp.audio_features('7tr2za8SQg2CI8EDgrdtNl')[0].keys())
     
     )

    df.rename(columns={'uri':'song_uri'}, inplace=True)

    df.drop_duplicates(subset=['artist', 'track', 'release_date'], inplace=True)
    
    return df

# %%
def get_audio_features(df):
  # prevent error 429 by waiting 30 seconds before sending request
  time.sleep(30)    
  # Send 50 tracks per request
  batchsize = 50

  # feature lists
  acousticness = []
  instrumentalness = []
  mode = []
  time_signature = []
  energy =[]
  loudness =[]
  speechiness = []
  valence = []
  liveness =[]
  tempo = []
  danceability =[]
  key = []
  duration = []
  popularity = []

  # iterate through each track in batches of 50 songs
  for i in range(0,df.shape[0], batchsize):
    uris = []
    batch = df[i:i+batchsize].reset_index()
    # add each song uri to the uris array
    for track in range(0,batch.shape[0], 1):
      # list of up to 100 uris
      uris.append(batch.iloc[track]['song_uri'])

    # gets audio features of the 100 uris
    features = sp.audio_features(uris)
    tracks= sp.tracks(uris)
    
    for i in range(len(features)):
      if features[i] != None:
        popularity.append(tracks['tracks'][i]['popularity'])
        energy.append(features[i]['energy'])
        acousticness.append(features[i]['acousticness'])
        instrumentalness.append(features[i]['instrumentalness'])
        mode.append(features[i]['mode'])
        time_signature.append(features[i]['time_signature'])
        loudness.append(features[i]['loudness'])
        speechiness.append(features[i]['speechiness'])
        valence.append(features[i]['valence'])
        liveness.append(features[i]['liveness'])
        tempo.append(features[i]['tempo'])
        danceability.append(features[i]['danceability'])
        key.append(features[i]['key'])
        duration.append(features[i]['duration_ms'])
      else:
        popularity.append(0)
        energy.append(0)
        acousticness.append(0)
        instrumentalness.append(0)
        mode.append(0)
        time_signature.append(0)
        loudness.append(0)
        speechiness.append(0)
        valence.append(0)
        liveness.append(0)
        tempo.append(0)
        danceability.append(0)
        key.append(0)
        duration.append(0)

  # Add Columns to Dataframe
  df['popularity'] = popularity
  df['energy'] = energy
  df['acousticness'] = acousticness
  df['instrumentalness'] = instrumentalness
  df['mode'] = mode
  df['time_signature'] = time_signature
  df['loudness'] = loudness
  df['speechiness'] = speechiness
  df['valence'] = valence
  df['liveness'] = liveness
  df['tempo'] = tempo
  df['danceability'] = danceability
  df['key'] = key
  df['duration'] = duration

  # rearrange columns
  cols = ['track', 'album_name', 'release_date', 'album_uri', 'song_uri', 'popularity',
              'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness',
              'loudness', 'speechiness', 'tempo', 'time_signature', 'mode', 'key', 'valence', 'duration', ]
  df= df[cols]
        
  return df

# %%
def get_artist_tracklist(artist):
    tracks = artist_all_tracks(artist)
    tracklist = df_tracks(tracks)
    features = get_audio_features(tracklist)
    return features

# %%
artist = 'Kendrick Lamar'
df = get_artist_tracklist(artist)
# Out:
# 0it [00:00, ?it/s]

# %%
df.sort_values(by=['popularity'], ascending=False)
# Out:
#                track      album_name release_date  \
# 2       Pink + White          Blonde   2016-08-20
# 18  Thinkin Bout You  channel ORANGE   2012-07-10
# 27              Lost  channel ORANGE   2012-07-10
# 1                Ivy          Blonde   2016-08-20
# 13     White Ferrari          Blonde   2016-08-20
# 8             Nights          Blonde   2016-08-20
# 26          Pyramids  channel ORANGE   2012-07-10
# 23   Super Rich Kids  channel ORANGE   2012-07-10
# 31       Pink Matter  channel ORANGE   2012-07-10
# 6       Self Control          Blonde   2016-08-20
# 15          Godspeed          Blonde   2016-08-20
# 25        Crack Rock  channel ORANGE   2012-07-10
# 0              Nikes          Blonde   2016-08-20
# 4               Solo          Blonde   2016-08-20
# 14         Seigfried          Blonde   2016-08-20
# 21        Sweet Life  channel ORANGE   2012-07-10
# 32      Forrest Gump  channel ORANGE   2012-07-10
# 30      Bad Religion  channel ORANGE   2012-07-10
# 20      Sierra Leone  channel ORANGE   2012-07-10
# 12      Close To You          Blonde   2016-08-20
# 5         Skyline To          Blonde   2016-08-20
# 28             White  channel ORANGE   2012-07-10
# 29             Monks  channel ORANGE   2012-07-10
# 7           Good Guy          Blonde   2016-08-20
# 24       Pilot Jones  channel ORANGE   2012-07-10
# 19        Fertilizer  channel ORANGE   2012-07-10
# 9     Solo (Reprise)          Blonde   2016-08-20
# 16       Futura Free          Blonde   2016-08-20
# 3        Be Yourself          Blonde   2016-08-20
# 10      Pretty Sweet          Blonde   2016-08-20
# 33               End  channel ORANGE   2012-07-10
# 22    Not Just Money  channel ORANGE   2012-07-10
# 11    Facebook Story          Blonde   2016-08-20
# 17             Start  channel ORANGE   2012-07-10
#
#                                album_uri  \
# 2   spotify:album:3mH6qwIy9crq0I9YQbOuDf
# 18  spotify:album:392p3shh2jkxUxY2VHvlH8
# 27  spotify:album:392p3shh2jkxUxY2VHvlH8
# 1   spotify:album:3mH6qwIy9crq0I9YQbOuDf
# 13  spotify:album:3mH6qwIy9crq0I9YQbOuDf
# 8   spotify:album:3mH6qwIy9crq0I9YQbOuDf
# 26  spotify:album:392p3shh2jkxUxY2VHvlH8
# 23  spotify:album:392p3shh2jkxUxY2VHvlH8
# 31  spotify:album:392p3shh2jkxUxY2VHvlH8
# 6   spotify:album:3mH6qwIy9crq0I9YQbOuDf
# 15  spotify:album:3mH6qwIy9crq0I9YQbOuDf
# 25  spotify:album:392p3shh2jkxUxY2VHvlH8
# 0   spotify:album:3mH6qwIy9crq0I9YQbOuDf
# 4   spotify:album:3mH6qwIy9crq0I9YQbOuDf
# 14  spotify:album:3mH6qwIy9crq0I9YQbOuDf
# 21  spotify:album:392p3shh2jkxUxY2VHvlH8
# 32  spotify:album:392p3shh2jkxUxY2VHvlH8
# 30  spotify:album:392p3shh2jkxUxY2VHvlH8
# 20  spotify:album:392p3shh2jkxUxY2VHvlH8
# 12  spotify:album:3mH6qwIy9crq0I9YQbOuDf
# 5   spotify:album:3mH6qwIy9crq0I9YQbOuDf
# 28  spotify:album:392p3shh2jkxUxY2VHvlH8
# 29  spotify:album:392p3shh2jkxUxY2VHvlH8
# 7   spotify:album:3mH6qwIy9crq0I9YQbOuDf
# 24  spotify:album:392p3shh2jkxUxY2VHvlH8
# 19  spotify:album:392p3shh2jkxUxY2VHvlH8
# 9   spotify:album:3mH6qwIy9crq0I9YQbOuDf
# 16  spotify:album:3mH6qwIy9crq0I9YQbOuDf
# 3   spotify:album:3mH6qwIy9crq0I9YQbOuDf
# 10  spotify:album:3mH6qwIy9crq0I9YQbOuDf
# 33  spotify:album:392p3shh2jkxUxY2VHvlH8
# 22  spotify:album:392p3shh2jkxUxY2VHvlH8
# 11  spotify:album:3mH6qwIy9crq0I9YQbOuDf
# 17  spotify:album:392p3shh2jkxUxY2VHvlH8
#
#                                 song_uri  popularity  acousticness  \
# 2   spotify:track:3xKsf9qdS1CyvXSMEid6g8          90        0.6670
# 18  spotify:track:7DfFc7a6Rwfi3YQMRbDMau          86        0.4090
# 27  spotify:track:3GZD6HmiNUhxXYf8Gch723          85        0.0272
# 1   spotify:track:2ZWlPOoWh0626oTaHrnl2a          83        0.7850
# 13  spotify:track:2LMkwUfqC6S6s6qDVlEuzV          82        0.7700
# 8   spotify:track:7eqoqGkKwgOaWNNHx90uEZ          80        0.4270
# 26  spotify:track:4QhWbupniDd44EDtnh2bFJ          79        0.0118
# 23  spotify:track:0725YWm6Z0TpZ6wrNk64Eb          78        0.2190
# 31  spotify:track:1fOkmYW3ZFkkjIdOZSf596          78        0.9510
# 6   spotify:track:5GUYJTQap5F3RDQiCOJhrS          77        0.7680
# 15  spotify:track:34xTFwjPQ1dC6uJmleno7x          76        0.9290
# 25  spotify:track:5lcyIeEfwZTs8Ajw3kdF7P          72        0.0696
# 0   spotify:track:19YKaevk2bce4odJkP5L22          72        0.6920
# 4   spotify:track:35xSkNIXi504fcEwz9USRB          71        0.8500
# 14  spotify:track:1BViPjTT585XAhkUUrkts0          71        0.9750
# 21  spotify:track:6MEDfjHxnVNcYmHe3mM6L2          70        0.2270
# 32  spotify:track:4YZbVct8l9MnAVIROnLQdx          70        0.0888
# 30  spotify:track:2pMPWE7PJH1PizfgGRMnR9          69        0.7380
# 20  spotify:track:1HwbgJAU9PZ7YbzKgVgoIF          68        0.1660
# 12  spotify:track:1VZLEW5ZfcAbKZ94XQiSZF          67        0.1940
# 5   spotify:track:4xR3MAscflQ262kMeiKshQ          66        0.8820
# 28  spotify:track:1VMdwVq0yaTc4DeqSCi7DO          66        0.7580
# 29  spotify:track:0msrDPXxZpts4FRnoX0bFr          65        0.0521
# 7   spotify:track:2JUqYobT8NvARdPmc4ES2x          64        0.9830
# 24  spotify:track:2ohegz9maxzroKBu9YhcCM          64        0.4850
# 19  spotify:track:6jypaMkKsoc5npsVzxhksl          63        0.6890
# 9   spotify:track:2qtoRFCOEL1gRn5q9DJC7F          63        0.4130
# 16  spotify:track:5k8LB57xOq8UUNVaKWSqrf          63        0.7690
# 3   spotify:track:1IdZvb2XK8NmsovQlV6CPn          63        0.9850
# 10  spotify:track:17yrCsl1Ai6CZLBmGj6d6p          62        0.2580
# 33  spotify:track:05tFLPSXJ1BbqIXy4Jeqfh          61        0.3830
# 22  spotify:track:3iW3y326xuRpNVXzOMBZy5          58        0.7750
# 11  spotify:track:73D5hBkiVZkopZrmBZTBWf          58        0.8730
# 17  spotify:track:0GAE689kVy7sFT2QWZH1Xa          57        0.7400
#
#     danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 2          0.545  0.5450          0.000055    0.4170    -7.362       0.1070
# 18         0.721  0.3390          0.001530    0.0973   -11.195       0.0532
# 27         0.913  0.6030          0.000503    0.1670    -4.892       0.2260
# 1          0.575  0.3860          0.000289    0.2290    -9.584       0.0370
# 13         0.501  0.0958          0.000000    0.2980   -15.605       0.0433
# 8          0.457  0.5510          0.000001    0.1130    -9.360       0.1670
# 26         0.400  0.6500          0.000076    0.7910    -6.104       0.0466
# 23         0.739  0.4190          0.000000    0.1960    -8.241       0.0854
# 31         0.392  0.2330          0.000322    0.1060   -11.012       0.0587
# 6          0.581  0.2100          0.000000    0.3690   -10.426       0.0321
# 15         0.399  0.0969          0.000168    0.1210   -12.578       0.0509
# 25         0.429  0.7360          0.000000    0.0852    -8.017       0.2220
# 0          0.633  0.3950          0.000222    0.1080    -9.638       0.0857
# 4          0.469  0.2890          0.000002    0.1610   -10.625       0.0366
# 14         0.377  0.2530          0.000259    0.1010   -11.155       0.0387
# 21         0.479  0.5580          0.000000    0.0808    -6.074       0.1790
# 32         0.701  0.4170          0.000648    0.3750    -7.818       0.0329
# 30         0.359  0.3670          0.000001    0.0736    -7.684       0.0335
# 20         0.529  0.6080          0.018500    0.1090    -7.809       0.0811
# 12         0.855  0.6630          0.001300    0.1460    -8.401       0.2000
# 5          0.430  0.2960          0.000006    0.1040   -13.645       0.0583
# 28         0.608  0.0664          0.945000    0.0978   -18.857       0.0596
# 29         0.747  0.7580          0.000000    0.2140    -4.743       0.1790
# 7          0.525  0.1310          0.004330    0.1200   -12.787       0.4580
# 24         0.394  0.4330          0.000078    0.8170   -13.473       0.3740
# 19         0.706  0.5700          0.069800    0.2880    -7.129       0.0841
# 9          0.669  0.7490          0.000000    0.0848    -6.811       0.1410
# 16         0.266  0.6780          0.000094    0.5030   -12.364       0.5080
# 3          0.746  0.4290          0.000000    0.1490   -11.143       0.4940
# 10         0.202  0.7240          0.025200    0.2960    -6.742       0.0494
# 33         0.476  0.2990          0.752000    0.0878   -17.997       0.1310
# 22         0.357  0.8270          0.021300    0.4930   -15.868       0.4440
# 11         0.526  0.1790          0.000000    0.2480   -20.550       0.6920
# 17         0.347  0.3300          0.931000    0.5570   -19.761       0.1490
#
#       tempo  time_signature  mode  key  valence  duration
# 2   159.940               3     1    9   0.5490    184516
# 18  129.830               4     1    0   0.2000    200747
# 27  123.061               4     1    8   0.4970    234093
# 1   116.408               4     0    9   0.4660    249191
# 13  108.741               4     1    0   0.2040    248808
# 8    89.870               4     0    5   0.4280    307151
# 26  107.989               4     0    5   0.1500    592920
# 23   60.493               4     0    3   0.5800    304760
# 31  176.569               3     0   11   0.4940    268813
# 6    80.099               4     1    8   0.4520    249668
# 15  109.540               4     1    6   0.0758    177922
# 25   89.262               4     1    5   0.3790    224147
# 0   138.023               4     1    8   0.1230    314075
# 4   133.805               4     0    5   0.2580    257380
# 14  125.403               3     0    4   0.3670    334570
# 21   83.465               4     1   11   0.8000    262680
# 32   95.003               4     0    6   0.1860    194840
# 30   83.331               4     1    9   0.1040    175453
# 20  125.017               4     1    7   0.6160    148760
# 12   77.978               4     0    5   0.8150     85754
# 5   129.048               4     1    3   0.3860    184600
# 28  139.232               4     1    1   0.2940     76280
# 29  102.020               4     0    0   0.6010    200240
# 7   107.007               5     1    0   0.8110     66786
# 24  118.988               1     1    8   0.3940    184080
# 19  115.864               4     1   11   0.9600     39640
# 9    80.169               4     0    7   0.6080     78743
# 16   83.434               4     1    1   0.2010    564166
# 3    88.413               3     1    7   0.9320     86944
# 10  154.037               4     1    0   0.1650    158478
# 33  119.487               4     1    2   0.3840    134600
# 22  152.130               1     0   11   0.1030     59760
# 11   81.993               3     1    0   0.6980     68588
# 17   82.850               5     1    7   0.0316     45640

# %%
artist = artist.replace(' ', '_').lower()+'.csv'
df.to_csv('tracks/'+ artist)
